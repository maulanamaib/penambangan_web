# %%
https://www.antaranews.com/berita/3855282/presiden-jokowi-tunjuk-marthinus-hukom-jadi-kepala-bnn
https://www.antaranews.com/berita/3853461/dejan-gloria-paparkan-kunci-juarai-turnamen-super-300-perdana-di-india?utm_source=antaranews&utm_medium=desktop&utm_campaign=menu_news
https://www.antaranews.com/berita/3853809/sasa-ramaikan-event-otomotif-decemblar-kustom-weekender-di-ancol?utm_source=antaranews&utm_medium=desktop&utm_campaign=menu_news

# %%
url = "https://www.antaranews.com/" #menentukan url

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser') #Isi teks dari respons HTTP yang diterima dari server web setelah melakukan permintaan GET.
# pages = soup.findAll('article', {'class' :'list-content__item'})
first_page = soup.findAll('li',"dropdown mega-full menu-color1") #menemukan semua list yang berisi link kategori

# print(first_page)
save_categori = []
for links in first_page:
  categori = links.find('a').get('href')
  save_categori.append(categori)
save_categori
# Out:
# ['https://www.antaranews.com/',
#  'https://www.antaranews.com/politik',
#  'https://www.antaranews.com/hukum',
#  'https://www.antaranews.com/ekonomi',
#  'https://www.antaranews.com/metro',
#  'https://www.antaranews.com/sepakbola',
#  'https://www.antaranews.com/olahraga',
#  'https://www.antaranews.com/humaniora',
#  'https://www.antaranews.com/lifestyle',
#  'https://www.antaranews.com/hiburan',
#  'https://www.antaranews.com/dunia',
#  'https://en.antaranews.com']

# %%
categori_search = [save_categori[1],save_categori[6],save_categori[8]] #categori yang akan disearch terdapat pada indeks 1,3,6
categori_search
# Out:
# ['https://www.antaranews.com/politik',
#  'https://www.antaranews.com/olahraga',
#  'https://www.antaranews.com/lifestyle']

# %%
datas=[]

for ipages in range(1,17):
  for beritas in categori_search:
    # print(beritas)
    response_berita = requests.get(beritas+"/"+str(ipages))
    namecategori = beritas.split("/")
    soup_berita = BeautifulSoup(response_berita.text, 'html.parser')
    pages_berita = soup_berita.findAll('article', {'class' :'simple-post simple-big clearfix'})

    i = 0
    for items in pages_berita:
      i += 1
      get_link_in = items.find("a").get("href")
      response_artikel = requests.get(get_link_in)
      soup_artikel = BeautifulSoup(response_artikel.text, 'html.parser')

      cek_judul = soup_artikel.findAll("h1","post-title")
      if cek_judul:
        judul = soup_artikel.find("h1","post-title").text
      else:
        judul=""

      label = namecategori[-1]

      try:
        date = soup_artikel.find("span", "article-date").text
      except AttributeError:
          date = "Data tanggal tidak ditemukan"
      cek_baca_juga = soup_artikel.findAll("span","baca-juga")
      trash1 = ""
      if cek_baca_juga:
        for bacas in cek_baca_juga:
          text_trash = bacas.text
          trash1 += text_trash + ' '
      else:
        trash1 = ""

      artikels = soup_artikel.find_all('div', {'class' :'post-content clearfix'})
      if artikels:
        artikel_content = soup_artikel.find('div', {'class' :'post-content clearfix'}).text
        artikel = artikel_content.replace("\n"," ").replace("\t"," ").replace("\r"," ").replace(trash1,"").replace("\xa0","")
      else:
        artikel = ""
      cek_author = soup_artikel.findAll("p","text-muted small mt10")
      if cek_author:
        author = soup_artikel.find("p","text-muted small mt10").text.replace("\t\t"," ")
      else:
        author = ""
      datas.append({
      'Tanggal' : date,
      'Penulis':author,
      'Judul': judul,
      'Artikel': artikel,
      'Label' :  label
          })

# %%
len(datas)
# Out:
# 720

# %%
# Menyimpan data dalam bentuk CSV
import csv
csv_filename = '/content/drive/MyDrive/ppw/tugasdata_antaranews.csv'
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Tanggal', 'Penulis', 'Judul', 'Artikel', 'Label']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for entry in datas:
        csv_writer.writerow(entry)

print(f"Data telah disimpan dalam file {csv_filename}")
# Out:
# Data telah disimpan dalam file /content/drive/MyDrive/ppw/tugasdata_antaranews.csv

# %%
data = pd.read_csv("/content/drive/MyDrive/ppw/tugasdata_antaranews.csv")
data
# Out:
#                                 Tanggal  \
# 0      Senin, 4 Desember 2023 21:28 WIB
# 1      Senin, 4 Desember 2023 21:25 WIB
# 2      Senin, 4 Desember 2023 20:58 WIB
# 3      Senin, 4 Desember 2023 20:41 WIB
# 4      Senin, 4 Desember 2023 20:30 WIB
# ..                                  ...
# 715   Kamis, 16 November 2023 17:50 WIB
# 716   Kamis, 16 November 2023 17:43 WIB
# 717   Kamis, 16 November 2023 16:21 WIB
# 718   Kamis, 16 November 2023 15:56 WIB
# 719   Kamis, 16 November 2023 11:10 WIB
#
#                                                Penulis  \
# 0                                                  NaN
# 1    Pewarta: Luqman HakimEditor: Laode Masrafi  CO...
# 2    Pewarta: Azmi Syamsul Ma'arifEditor: Laode Mas...
# 3    Pewarta: Rangga Pandu Asmara JinggaEditor: Gui...
# 4                                                  NaN
# ..                                                 ...
# 715  Pewarta: Vinny Shoffa SalmaEditor: Siti Zulaik...
# 716  Pewarta: Fitra AshariEditor: Siti Zulaikha  CO...
# 717  Pewarta: Fitra AshariEditor: Siti Zulaikha  CO...
# 718  Penerjemah: Nabil IhsanEditor: Maria Rosari Dw...
# 719  Pewarta: Lia Wanadriani SantosaEditor: Maria R...
#
#                                                  Judul  \
# 0    Gibran blusukan ke Poris Tangerang bagikan sus...
# 1    Sultan HB X tegaskan keistimewaan DIY dilindun...
# 2    TKN Prabowo-Gibran beri gagasan kemandirian ek...
# 3    Presiden Jokowi tunjuk Marthinus Hukom jadi Ke...
# 4             Militer Israel kembali gempur Jalur Gaza
# ..                                                 ...
# 715  The Body Shop donasikan Rp1 miliar untuk dana ...
# 716  Mengenal tiga hormon penting pada masa kehamil...
# 717  Penurunan hormon pasca melahirkan dapat menyeb...
# 718  "Kata Tahun Ini" Cambridge Dictionary tunjukka...
# 719           Begini kiat mengolah daging agar "juicy"
#
#                                                Artikel      Label
# 0                         ANTARA - Calon Wakil Pres...    politik
# 1         Yogyakarta (ANTARA) - Gubernur Daerah Ist...    politik
# 2         Tangerang (ANTARA) - Tim Kampanye Nasiona...    politik
# 3         Jakarta (ANTARA) - Presiden Joko Widodo m...    politik
# 4                                                  NaN    politik
# ..                                                 ...        ...
# 715       Jakarta (ANTARA) - Jenama produk kecantik...  lifestyle
# 716       Jakarta (ANTARA) - Pada masa kehamilan, b...  lifestyle
# 717       Jakarta (ANTARA) - Dokter spesialis obste...  lifestyle
# 718       Jakarta (ANTARA) - Kamus Bahasa Inggris C...  lifestyle
# 719       Jakarta (ANTARA) - Ada cara agar hasil ol...  lifestyle
#
# [720 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Tanggal      0
# Penulis    102
# Judul       14
# Artikel     50
# Label        0
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#                                 Tanggal  \
# 1      Senin, 4 Desember 2023 21:25 WIB
# 2      Senin, 4 Desember 2023 20:58 WIB
# 3      Senin, 4 Desember 2023 20:41 WIB
# 5      Senin, 4 Desember 2023 20:29 WIB
# 7      Senin, 4 Desember 2023 20:04 WIB
# ..                                  ...
# 715   Kamis, 16 November 2023 17:50 WIB
# 716   Kamis, 16 November 2023 17:43 WIB
# 717   Kamis, 16 November 2023 16:21 WIB
# 718   Kamis, 16 November 2023 15:56 WIB
# 719   Kamis, 16 November 2023 11:10 WIB
#
#                                                Penulis  \
# 1    Pewarta: Luqman HakimEditor: Laode Masrafi  CO...
# 2    Pewarta: Azmi Syamsul Ma'arifEditor: Laode Mas...
# 3    Pewarta: Rangga Pandu Asmara JinggaEditor: Gui...
# 5    Pewarta: FauziEditor: Laode Masrafi  COPYRIGHT...
# 7    Pewarta: Dian HadiyatnaEditor: Guido Merung  C...
# ..                                                 ...
# 715  Pewarta: Vinny Shoffa SalmaEditor: Siti Zulaik...
# 716  Pewarta: Fitra AshariEditor: Siti Zulaikha  CO...
# 717  Pewarta: Fitra AshariEditor: Siti Zulaikha  CO...
# 718  Penerjemah: Nabil IhsanEditor: Maria Rosari Dw...
# 719  Pewarta: Lia Wanadriani SantosaEditor: Maria R...
#
#                                                  Judul  \
# 1    Sultan HB X tegaskan keistimewaan DIY dilindun...
# 2    TKN Prabowo-Gibran beri gagasan kemandirian ek...
# 3    Presiden Jokowi tunjuk Marthinus Hukom jadi Ke...
# 5    DEEP: KPU diskusikan dengan para pihak sebelum...
# 7    Prabowo-Gibran satu putaran karena survei di t...
# ..                                                 ...
# 715  The Body Shop donasikan Rp1 miliar untuk dana ...
# 716  Mengenal tiga hormon penting pada masa kehamil...
# 717  Penurunan hormon pasca melahirkan dapat menyeb...
# 718  "Kata Tahun Ini" Cambridge Dictionary tunjukka...
# 719           Begini kiat mengolah daging agar "juicy"
#
#                                                Artikel      Label
# 1         Yogyakarta (ANTARA) - Gubernur Daerah Ist...    politik
# 2         Tangerang (ANTARA) - Tim Kampanye Nasiona...    politik
# 3         Jakarta (ANTARA) - Presiden Joko Widodo m...    politik
# 5         Jakarta (ANTARA) -   Direktur Eksekutif D...    politik
# 7         Bandarlampung (ANTARA) - Dewan Pembina Re...    politik
# ..                                                 ...        ...
# 715       Jakarta (ANTARA) - Jenama produk kecantik...  lifestyle
# 716       Jakarta (ANTARA) - Pada masa kehamilan, b...  lifestyle
# 717       Jakarta (ANTARA) - Dokter spesialis obste...  lifestyle
# 718       Jakarta (ANTARA) - Kamus Bahasa Inggris C...  lifestyle
# 719       Jakarta (ANTARA) - Ada cara agar hasil ol...  lifestyle
#
# [618 rows x 5 columns]
